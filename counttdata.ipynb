# %%
import pandas as pd
import numpy as np 
df=pd.read_csv('locations.csv')
df
# Out:
#                                       Location         Latitude / Longitude
# 0                         Bell Rock Lighthouse     56.43416667,-2.387222222
# 1                                          NaN     40.70555556,-73.99638889
# 2                  Catacombs of Kom el Shoqafa          31.178558,29.892954
# 3                               Channel Tunnel               51.0125,1.5041
# 4                                 Chichen Itza     20.68277778,-88.56861111
# 5                   Christ the Redeemer Statue    -21.04805556,-43.21055556
# 6                                     CN Tower             43.6426,-79.3871
# 7                                    Colosseum            41.89,12.49222222
# 8                           Colossus of Rhodes              36.4511,28.2278
# 9                Delta Works / Zuiderzee Works                   51.65,3.72
# 10                       Empire State Building     40.74833333,-73.98555556
# ...

# %%
#Count Distinct calues-Descending
df['Location'].value_counts()
# Out:
# Location
# Bell Rock Lighthouse                          1
# Catacombs of Kom el Shoqafa                   1
# Channel Tunnel                                1
# Chichen Itza                                  1
# Christ the Redeemer Statue                    1
# CN Tower                                      1
# Colosseum                                     1
# Colossus of Rhodes                            1
# Delta Works / Zuiderzee Works                 1
# Empire State Building                         1
# First Transcontinental Railroad               1
# Golden Gate Bridge                            1
# Grand Canyon                                  1
# Great Barrier Reef                            1
# Great Pyramid of Giza                         1
# Great Wall of China                           1
# Guanabara Bay                                 1
# Hagia Sophia                                  1
# Hanging Gardens of Babylon                    1
# ...

# %%
#Count Distinct Vlaues-Acesding
df['Location'].value_counts(ascending=True )
# Out:
# Location
# Bell Rock Lighthouse                          1
# Catacombs of Kom el Shoqafa                   1
# Channel Tunnel                                1
# Chichen Itza                                  1
# Christ the Redeemer Statue                    1
# CN Tower                                      1
# Colosseum                                     1
# Colossus of Rhodes                            1
# Delta Works / Zuiderzee Works                 1
# Empire State Building                         1
# First Transcontinental Railroad               1
# Golden Gate Bridge                            1
# Grand Canyon                                  1
# Great Barrier Reef                            1
# Great Pyramid of Giza                         1
# Great Wall of China                           1
# Guanabara Bay                                 1
# Hagia Sophia                                  1
# Hanging Gardens of Babylon                    1
# ...

# %%
#Location names-without NoN
df['Location'].value_counts()
# Out:
# Location
# Bell Rock Lighthouse                          1
# Catacombs of Kom el Shoqafa                   1
# Channel Tunnel                                1
# Chichen Itza                                  1
# Christ the Redeemer Statue                    1
# CN Tower                                      1
# Colosseum                                     1
# Colossus of Rhodes                            1
# Delta Works / Zuiderzee Works                 1
# Empire State Building                         1
# First Transcontinental Railroad               1
# Golden Gate Bridge                            1
# Grand Canyon                                  1
# Great Barrier Reef                            1
# Great Pyramid of Giza                         1
# Great Wall of China                           1
# Guanabara Bay                                 1
# Hagia Sophia                                  1
# Hanging Gardens of Babylon                    1
# ...

# %%
#Location names-with NoN
df['Location'].value_counts(dropna=False )
# Out:
# Location
# NaN                                           2
# Bell Rock Lighthouse                          1
# Catacombs of Kom el Shoqafa                   1
# Channel Tunnel                                1
# Chichen Itza                                  1
# Christ the Redeemer Statue                    1
# CN Tower                                      1
# Colosseum                                     1
# Colossus of Rhodes                            1
# Delta Works / Zuiderzee Works                 1
# Empire State Building                         1
# First Transcontinental Railroad               1
# Golden Gate Bridge                            1
# Grand Canyon                                  1
# Great Barrier Reef                            1
# Great Pyramid of Giza                         1
# Great Wall of China                           1
# Guanabara Bay                                 1
# Hagia Sophia                                  1
# ...

# %%
#Get Relaticve Frequency -Percentage
df['Location'].value_counts(normalize=True)
# Out:
# Location
# Bell Rock Lighthouse                          0.025641
# Catacombs of Kom el Shoqafa                   0.025641
# Channel Tunnel                                0.025641
# Chichen Itza                                  0.025641
# Christ the Redeemer Statue                    0.025641
# CN Tower                                      0.025641
# Colosseum                                     0.025641
# Colossus of Rhodes                            0.025641
# Delta Works / Zuiderzee Works                 0.025641
# Empire State Building                         0.025641
# First Transcontinental Railroad               0.025641
# Golden Gate Bridge                            0.025641
# Grand Canyon                                  0.025641
# Great Barrier Reef                            0.025641
# Great Pyramid of Giza                         0.025641
# Great Wall of China                           0.025641
# Guanabara Bay                                 0.025641
# ...

# %%
#Count Unique values -count
df.groupby('Location').count()
# Out:
#                                             Latitude / Longitude
# Location
# Bell Rock Lighthouse                                           1
# CN Tower                                                       1
# Catacombs of Kom el Shoqafa                                    1
# Channel Tunnel                                                 1
# Chichen Itza                                                   1
# Christ the Redeemer Statue                                     1
# Colosseum                                                      1
# Colossus of Rhodes                                             1
# Delta Works / Zuiderzee Works                                  1
# Empire State Building                                          1
# First Transcontinental Railroad                                1
# Golden Gate Bridge                                             1
# Grand Canyon                                                   1
# ...

# %%
#get a count of all colums across all colums
df.apply(pd.value_counts)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7800\4136839841.py:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   df.apply(pd.value_counts)
# C:\Users\User\AppData\Local\Temp\ipykernel_7800\4136839841.py:2: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   df.apply(pd.value_counts)
#                               Location  Latitude / Longitude
# -0.51,35.14388889                  NaN                   1.0
# -12.83666667,-72.54555556          NaN                   1.0
# -16.07555556,25.85666667           NaN                   1.0
# -17.71388889,147.7                 NaN                   1.0
# -21.04805556,-43.21055556          NaN                   1.0
# ...                                ...                   ...
# Statue of Zeus at Olympia          1.0                   NaN
# ...

# %%
#Get specific item count


df['Location'].value_counts()['Hoover Dam']
# Out:
# np.int64(1)

# %%
#cOUNT uNIQUE VALUES -sIZE
df.groupby('Location').size()
# Out:
# Location
# Bell Rock Lighthouse                          1
# CN Tower                                      1
# Catacombs of Kom el Shoqafa                   1
# Channel Tunnel                                1
# Chichen Itza                                  1
# Christ the Redeemer Statue                    1
# Colosseum                                     1
# Colossus of Rhodes                            1
# Delta Works / Zuiderzee Works                 1
# Empire State Building                         1
# First Transcontinental Railroad               1
# Golden Gate Bridge                            1
# Grand Canyon                                  1
# Great Barrier Reef                            1
# Great Pyramid of Giza                         1
# Great Wall of China                           1
# Guanabara Bay                                 1
# Hagia Sophia                                  1
# Hanging Gardens of Babylon                    1
# ...
