# %%
import pandas as pd
# %matplotlib inline
import numpy as np
from numpy.random import randn

#Create a quick dataframe
df=pd.DataFrame(randn(100,4),columns=["Mon","Tue","Wed","Thur"])
df
# Out:
#          Mon       Tue       Wed      Thur
# 0   0.439254 -0.627544 -1.345111  1.066041
# 1  -0.840507  0.593139  0.477366 -0.453873
# 2   0.076954  1.186089 -0.187063 -0.519207
# 3  -1.058662  1.469015 -0.458591  1.247874
# 4  -1.057496 -1.340827 -0.729127  0.503239
# ..       ...       ...       ...       ...
# 95 -0.112593 -0.249222 -2.435865  1.723016
# 96  1.829252  0.258072  1.246743  0.498152
# 97  0.716349  1.853058  0.629555  1.101109
# 98 -0.183159 -2.746555 -1.294289 -0.388966
# 99 -2.777152 -0.157869  0.069093 -0.970453
#
# [100 rows x 4 columns]

# %%
#Histogram
df["Wed"].hist()
# Out:
# <Axes: >

# %%
#hISTOGRAM WITH SMALLER BINS,50,20
df["Wed"].hist(bins=20)
# Out:
# <Axes: >

# %%
# aNOTHER WAY WITHOUT GRID BARS
df["Wed"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Wed"].hist(bins=20,grid=False,legend=True)
# Out:
# <Axes: >
